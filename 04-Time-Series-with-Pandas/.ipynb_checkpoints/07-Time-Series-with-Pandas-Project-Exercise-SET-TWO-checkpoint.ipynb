# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Time Series with Pandas Project Exercise
#
# For this exercise, answer the questions below given the dataset: https://fred.stlouisfed.org/series/UMTMVS
#
# This dataset is the Value of Manufacturers' Shipments for All Manufacturing Industries.

# %% [markdown]
# **Import any necessary libraries.**

# %%
# CODE HERE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# **Read in the data UMTMVS.csv file from the Data folder**

# %%
# CODE HERE
df = pd.read_csv('../Data/UMTMVS.csv',index_col='DATE',parse_dates=True)

# %% [markdown]
# **Check the head of the data**

# %%
# CODE HERE
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
df.index.day[:5]    # as its a time-indexed data we can get the data for day, month,year as an attribute
# Out:
# Int64Index([1, 1, 1, 1, 1], dtype='int64', name='DATE')

# %%
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %% [markdown]
# **Plot out the data, choose a reasonable figure size**

# %%
# CODE HERE
df.plot(figsize=(12,6));

# %% [markdown]
# **What was the percent increase in value from Jan 2009 to Jan 2019?**

# %%
#CODE HERE
((df.loc['2019-01-01']['UMTMVS'] - df.loc['2009-01-01']['UMTMVS'])/df.loc['2009-01-01']['UMTMVS'])*100
# Out:
# 38.47214929650164

# %%
# Out:
# UMTMVS    38.472149
# dtype: float64

# %% [markdown]
# **What was the percent decrease from Jan 2008 to Jan 2009?**

# %%
#CODE HERE
((df.loc['2009-01-01']['UMTMVS'] - df.loc['2008-01-01']['UMTMVS'])/df.loc['2008-01-01']['UMTMVS'])*100
# Out:
# -22.022775481313047

# %%
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %% [markdown]
# **What is the month with the least value after 2005?** [HINT](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmin.html)

# %%
#CODE HERE
df.loc['2005-01-01':,:].idxmin()  # using idxmin
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %%
df.loc['2005-01-01':,:].min()   # observe using slicing in the datetime index
# Out:
# UMTMVS    337101.0
# dtype: float64

# %%
df.loc['2009-01-01',:]
# Out:
# UMTMVS    337101.0
# Name: 2009-01-01 00:00:00, dtype: float64

# %%
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %% [markdown]
# **What 6 months have the highest value?**

# %%
# CODE HERE
df.sort_values(by = 'UMTMVS', ascending = False)[:6]
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
# Out:
#               UMTMVS    Yearly Mean
# DATE
# 2018-08-01  529157.0  490453.500000
# 2018-10-01  527031.0  496482.333333
# 2018-06-01  525660.0  483611.000000
# 2018-03-01  518285.0  474351.250000
# 2018-09-01  516992.0  493075.583333

# %% [markdown]
# **How many millions of dollars in value was lost in 2008? (Another way of posing this question is what was the value difference between Jan 2008 and Jan 2009)**

# %%
# CODE HERE
df.loc['2008-01-01','UMTMVS'] - df.loc['2009-01-01', 'UMTMVS']
# Out:
# 95206.0

# %%
# Out:
# UMTMVS    95206.0
# dtype: float64

# %% [markdown]
# **Create a bar plot showing the average value in millions of dollars per year**

# %%
# CODE HERE
df.resample('A').mean().plot(kind = 'bar', figsize = (13,7));

# %% [markdown]
# **What year had the biggest increase in mean value from the previous year's mean value? (Lots of ways to get this answer!)**
#
# [HINT for a useful method](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.idxmax.html)

# %%
# CODE HERE
yearly_data = df.resample('Y').mean()
yearly_data.head(5)
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
yearly_data_shift = yearly_data.shift(1)
yearly_data_shift.head()
# Out:
#                    UMTMVS
# DATE
# 1992-12-31            NaN
# 1993-12-31  242002.000000
# 1994-12-31  251708.083333
# 1995-12-31  269842.666667
# 1996-12-31  289973.083333

# %%
change = yearly_data - yearly_data_shift
change.head(8)
# Out:
#                   UMTMVS
# DATE
# 1992-12-31           NaN
# 1993-12-31   9706.083333
# 1994-12-31  18134.583333
# 1995-12-31  20130.416667
# 1996-12-31   9792.583333
# 1997-12-31  19792.583333
# 1998-12-31   5426.166667
# 1999-12-31  11006.166667

# %%
change.idxmax()
# Out:
# UMTMVS   2011-12-31
# dtype: datetime64[ns]

# %%
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %% [markdown]
# **Plot out the yearly rolling mean on top of the original data. Recall that this is monthly data and there are 12 months in a year!**

# %%
df['Yearly rolling mean'] = df['UMTMVS'].rolling(window=12).mean()
df.head()
# Out:
#               UMTMVS  Yearly rolling mean
# DATE
# 1992-01-01  209438.0                  NaN
# 1992-02-01  232679.0                  NaN
# 1992-03-01  249673.0                  NaN
# 1992-04-01  239666.0                  NaN
# 1992-05-01  243231.0                  NaN

# %%
# CODE HERE
df.plot(figsize=(12,6));

# %% [markdown]
# **BONUS QUESTION (HARD).**
#
# **Some month in 2008 the value peaked for that year. How many months did it take to surpass that 2008 peak? (Since it crashed immediately after this peak) There are many ways to get this answer. NOTE: I get 70 months as my answer, you may get 69 or 68, depending on whether or not you count the start and end months. Refer to the video solutions for full explanation on this.**

# %%
df.drop(columns = 'Yearly rolling mean', inplace = True)
df.loc[df.index.year==2008,]
# Out:
#               UMTMVS
# DATE
# 2008-01-01  432307.0
# 2008-02-01  442996.0
# 2008-03-01  474592.0
# 2008-04-01  475667.0
# 2008-05-01  490500.0
# 2008-06-01  510081.0
# 2008-07-01  476948.0
# 2008-08-01  482530.0
# 2008-09-01  471799.0
# 2008-10-01  450521.0
# 2008-11-01  383475.0
# 2008-12-01  377578.0

# %%
df.loc[df.index.year==2008, 'UMTMVS'].idxmax()
# Out:
# Timestamp('2008-06-01 00:00:00')

# %%
df.loc[df.index.year==2008].max()
# Out:
# UMTMVS    510081.0
# dtype: float64

# %%
df_post_peak = df.loc['2008-06-01':,]

# %%
df_post_peak[df_post_peak >= df.loc[df.index.year==2008].max()].dropna()
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
#CODE HERE
len(df.loc['2008-06-01':'2014-03-01'])-1 # not counting the staring month of 2008-06-01
# Out:
# 69

# %%
# Out:
# 70

# %% [markdown]
# # GREAT JOB!
